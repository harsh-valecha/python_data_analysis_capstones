# %% [markdown]
# ## CSV Practice

# %%
import csv

# %%
with open('practice_data.csv','r') as f:
    reader = csv.reader(f)
    for rows in reader:
        print(rows)
# Out:
# ['id', 'first_name', 'last_name', 'email', 'age', 'city', 'country', 'department', 'salary', 'active']
# ['1', 'Ava', 'Patel', 'ava.patel@example.com', '29', 'New York', 'USA', 'Engineering', '95000', 'yes']
# ['2', 'Liam', 'Nguyen', 'liam.nguyen@example.com', '34', 'Seattle', 'USA', 'Marketing', '78000', 'yes']
# ['3', 'Sofia', 'Martinez', 'sofia.martinez@example.com', '27', 'Barcelona', 'Spain', 'Sales', '68000', 'yes']
# ['4', 'Noah', 'Kim', 'noah.kim@example.com', '31', 'Seoul', 'South Korea', 'Finance', '82000', 'no']
# ['5', 'Emma', 'Johnson', 'emma.johnson@example.com', '26', 'London', 'UK', 'Support', '61000', 'yes']
# ['6', 'Lucas', 'Silva', 'lucas.silva@example.com', '38', 'Sao Paulo', 'Brazil', 'Operations', '74000', 'yes']
# ['7', 'Mila', 'Schmidt', 'mila.schmidt@example.com', '24', 'Berlin', 'Germany', 'HR', '59000', 'yes']
# ['8', 'James', 'Ali', 'james.ali@example.com', '41', 'Doha', 'Qatar', 'Engineering', '105000', 'yes']
# ...

# %%
f_read = open('practice_data.csv','r')
dicter = csv.DictReader(f_read)
for row in dicter:
    print(row)
# Out:
# {'id': '1', 'first_name': 'Ava', 'last_name': 'Patel', 'email': 'ava.patel@example.com', 'age': '29', 'city': 'New York', 'country': 'USA', 'department': 'Engineering', 'salary': '95000', 'active': 'yes'}
# {'id': '2', 'first_name': 'Liam', 'last_name': 'Nguyen', 'email': 'liam.nguyen@example.com', 'age': '34', 'city': 'Seattle', 'country': 'USA', 'department': 'Marketing', 'salary': '78000', 'active': 'yes'}
# {'id': '3', 'first_name': 'Sofia', 'last_name': 'Martinez', 'email': 'sofia.martinez@example.com', 'age': '27', 'city': 'Barcelona', 'country': 'Spain', 'department': 'Sales', 'salary': '68000', 'active': 'yes'}
# {'id': '4', 'first_name': 'Noah', 'last_name': 'Kim', 'email': 'noah.kim@example.com', 'age': '31', 'city': 'Seoul', 'country': 'South Korea', 'department': 'Finance', 'salary': '82000', 'active': 'no'}
# ...
